# %% [markdown]
# ## Extension of Notebook for solving linear regression using the batch/mini-batch/stochastic gradient descent

# %% [markdown]
# ## Imports

# %%
import numpy as np
# %matplotlib inline
from mpl_toolkits import mplot3d
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
np.random.seed(42)

# generate m random pairs (x, y)
m = 100
x1 = 2 * np.random.rand(m, 1)
x2 = 2 * np.random.rand(m, 1)
y = 4 + 2 * x1 + 7 * x2 + np.random.rand(m, 1)

# Show data points 
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(x1, x2, y)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')
# Out:
# Text(0.5, 0, 'y')

# %%
# number of epochs
epochs = 20
# learning rate
lr = 0.01

# %%
# training set
trainx1 = x1[:80]
trainx2 = x2[:80]
trainy  =  y[:80]

# test set
testx1 = x1[80:]
testx2 = x2[80:]
testy  =  y[80:]

# weights
weight1 = np.random.randn(1)
weight2 = np.random.randn(1)
b   = np.zeros(1)

# %% [markdown]
# # Linear regression using mini-batch gradient descent
# A few training examples are selected to compute the gradient.

# %%
for epoch in np.arange(epochs):
  for i in np.arange(80):
    y_trained = weight1 * trainx1[i] + weight2 * trainx2[i] + b
    weight1_grad = (y_pred - trainy[i]) * trainx1[i]
    weight2_grad = (y_pred - trainy[i]) * trainx2[i]
    bias_grad    = (y_pred - trainy[i])
    weight1      = weight1 - lr * grad_w1
    weight2      = weight2 - lr * grad_w2
    b            = b - lr * grad_b

final_y = weight1 * testx1 + weight2 * testx2 + b

ax = plt.axes(projection='3d')
ax.scatter3D(testx1, testx2, testy)
ax.scatter3D(testx1, testx2, final_y)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')
# Out:
# Text(0.5, 0, 'y')
